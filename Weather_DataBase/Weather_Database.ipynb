# %%
#Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

#Import the datetime module from datetime library
#from datetime import datetime

#Import the requests library
import requests

#Import the API key
from config import weather_api_key

#Starting URL for Weather Map API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" +weather_api_key

# %%
#Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lats_lngs=zip(lats,lngs)
lats_lngs

# %%
#Add the lat and long combinations to a list
coordinates = list (lats_lngs)

# %%
#Create a list for holding the cities
cities=[]

# Identify the nearest city for each lat and long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If city is unique, add it to the cities list
    if city not in cities:
        cities.append(city)

#Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval")
print("------------------------")

#Create the counters
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# ------------------------

# %%
# Loop through all the cities in our list:
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i>=50):
        set_count +=1
        record_count +=1
        
    #Create end point URL with each city
    city_url = url+"&q="+city.replace(" ","+")
        
    #Log the URL, record, and set numbers in the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    #Increment record count
    record_count +=1
    
    # Run an API request for each of the cities
    try:
        #Parse the JSON and retreive data
        city_weather=requests.get(city_url).json()
        
        #Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_cur_cond = city_weather['weather'][0]['description']
        
    
        #Append the city information into city_data list
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat":city_lat,
                          "Lng":city_lng,
                          "Max Temp":city_max_temp,
                          "Humidity":city_humidity,
                          "Cloudiness":city_clouds,
                          "Wind Speed":city_wind, 
                          "Current Description":city_cur_cond})
    
    #If an error occurs, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Processing Record 1 of Set 1 | hamilton
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | husavik
# Processing Record 5 of Set 1 | fallon
# Processing Record 6 of Set 1 | sambava
# Processing Record 7 of Set 1 | hokitika
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | nome
# Processing Record 10 of Set 1 | santiago de cao
# Processing Record 11 of Set 1 | bengkulu
# Processing Record 12 of Set 1 | leshukonskoye
# Processing Record 13 of Set 1 | rio grande
# Processing Record 14 of Set 1 | saldanha
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | pochutla
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | midland
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | arraial do cabo
# Processing Record 22 of Set 1 | mount isa
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | guerrero negro
# Processing Record 25 of Set 1 | namalenga
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | sardarshahr
# Processing Record 28 of Set 1 | kavieng
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | nanzhang
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | kavaratti
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | puerto carreno
# Processing Record 39 of Set 1 | krasnyy chikoy
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | kieta
# Processing Record 42 of Set 1 | sorland
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 1 | bosaso
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 1 | praia da vitoria
# Processing Record 49 of Set 1 | palasa
# Processing Record 50 of Set 1 | mataura
# Processing Record 52 of Set 2 | minab
# Processing Record 53 of Set 2 | ilulissat
# Processing Record 54 of Set 2 | nelson bay
# Processing Record 55 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 56 of Set 2 | zhangye
# Processing Record 57 of Set 2 | tiksi
# Processing Record 58 of Set 2 | isangel
# Processing Record 59 of Set 2 | punta arenas
# Processing Record 60 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 61 of Set 2 | nikolskoye
# Processing Record 62 of Set 2 | caravelas
# Processing Record 63 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 64 of Set 2 | vestmanna
# Processing Record 65 of Set 2 | saint-philippe
# Processing Record 66 of Set 2 | bolgatanga
# Processing Record 67 of Set 2 | sistranda
# Processing Record 68 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 69 of Set 2 | souillac
# Processing Record 70 of Set 2 | port alfred
# Processing Record 71 of Set 2 | state college
# Processing Record 72 of Set 2 | thinadhoo
# Processing Record 73 of Set 2 | usinsk
# Processing Record 74 of Set 2 | kapaa
# Processing Record 75 of Set 2 | ilheus
# Processing Record 76 of Set 2 | bluff
# Processing Record 77 of Set 2 | lagoa
# Processing Record 78 of Set 2 | thompson
# Processing Record 79 of Set 2 | atuona
# Processing Record 80 of Set 2 | saskylakh
# Processing Record 81 of Set 2 | wajir
# Processing Record 82 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 83 of Set 2 | khatanga
# Processing Record 84 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 85 of Set 2 | hermanus
# Processing Record 86 of Set 2 | iwanai
# Processing Record 87 of Set 2 | longyearbyen
# Processing Record 88 of Set 2 | choucheng
# City not found. Skipping...
# Processing Record 89 of Set 2 | hobart
# Processing Record 90 of Set 2 | moindou
# Processing Record 91 of Set 2 | chuy
# Processing Record 92 of Set 2 | ponta do sol
# Processing Record 93 of Set 2 | san patricio
# Processing Record 94 of Set 2 | flinders
# Processing Record 95 of Set 2 | vaini
# Processing Record 96 of Set 2 | victoria
# Processing Record 97 of Set 2 | lunglei
# Processing Record 98 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 99 of Set 2 | inhambane
# Processing Record 100 of Set 2 | khanpur
# Processing Record 101 of Set 2 | padang
# Processing Record 103 of Set 3 | alyangula
# Processing Record 104 of Set 3 | qaanaaq
# Processing Record 105 of Set 3 | viedma
# Processing Record 106 of Set 3 | chokurdakh
# Processing Record 107 of Set 3 | castro
# Processing Record 108 of Set 3 | barrow
# Processing Record 109 of Set 3 | muros
# Processing Record 110 of Set 3 | vila franca do campo
# Processing Record 111 of Set 3 | sitka
# Processing Record 112 of Set 3 | albany
# Processing Record 113 of Set 3 | adrar
# Processing Record 114 of Set 3 | turukhansk
# Processing Record 115 of Set 3 | zeya
# Processing Record 116 of Set 3 | omboue
# Processing Record 117 of Set 3 | korla
# Processing Record 118 of Set 3 | koplik
# Processing Record 119 of Set 3 | aksay
# Processing Record 120 of Set 3 | geraldton
# Processing Record 121 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 122 of Set 3 | port hardy
# Processing Record 123 of Set 3 | san pedro
# Processing Record 124 of Set 3 | katsuura
# Processing Record 125 of Set 3 | touros
# Processing Record 126 of Set 3 | krasnyy kut
# Processing Record 127 of Set 3 | ulladulla
# Processing Record 128 of Set 3 | abu samrah
# Processing Record 129 of Set 3 | lebu
# Processing Record 130 of Set 3 | torbay
# Processing Record 131 of Set 3 | saint-augustin
# Processing Record 132 of Set 3 | forestville
# Processing Record 133 of Set 3 | acara
# Processing Record 134 of Set 3 | nizwa
# Processing Record 135 of Set 3 | edd
# Processing Record 136 of Set 3 | adjumani
# Processing Record 137 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 138 of Set 3 | kabakovo
# Processing Record 139 of Set 3 | puerto escondido
# Processing Record 140 of Set 3 | grado
# Processing Record 141 of Set 3 | kattivakkam
# Processing Record 142 of Set 3 | breves
# Processing Record 143 of Set 3 | falmouth
# Processing Record 144 of Set 3 | skjaerhollen
# City not found. Skipping...
# Processing Record 145 of Set 3 | zonguldak
# Processing Record 146 of Set 3 | guider
# Processing Record 147 of Set 3 | la libertad
# Processing Record 148 of Set 3 | cidreira
# Processing Record 149 of Set 3 | sobolevo
# Processing Record 150 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 151 of Set 3 | baoqing
# Processing Record 152 of Set 3 | tromso
# Processing Record 154 of Set 4 | kostrzyn
# Processing Record 155 of Set 4 | bethel
# Processing Record 156 of Set 4 | verkhnevilyuysk
# Processing Record 157 of Set 4 | ouro preto do oeste
# Processing Record 158 of Set 4 | manono
# Processing Record 159 of Set 4 | bodden town
# Processing Record 160 of Set 4 | mount gambier
# Processing Record 161 of Set 4 | georgetown
# Processing Record 162 of Set 4 | jijiga
# Processing Record 163 of Set 4 | esperance
# Processing Record 164 of Set 4 | aktau
# Processing Record 165 of Set 4 | iqaluit
# Processing Record 166 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 167 of Set 4 | hofn
# Processing Record 168 of Set 4 | dingle
# Processing Record 169 of Set 4 | dikson
# Processing Record 170 of Set 4 | eureka
# Processing Record 171 of Set 4 | dustlik
# Processing Record 172 of Set 4 | bredasdorp
# Processing Record 173 of Set 4 | bambous virieux
# Processing Record 174 of Set 4 | tuatapere
# Processing Record 175 of Set 4 | mahebourg
# Processing Record 176 of Set 4 | luderitz
# Processing Record 177 of Set 4 | along
# Processing Record 178 of Set 4 | skjervoy
# Processing Record 179 of Set 4 | labuhan
# Processing Record 180 of Set 4 | marsh harbour
# Processing Record 181 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 182 of Set 4 | doraha
# Processing Record 183 of Set 4 | tasiilaq
# Processing Record 184 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 185 of Set 4 | dawlatabad
# Processing Record 186 of Set 4 | byron bay
# Processing Record 187 of Set 4 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 188 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 189 of Set 4 | lima
# Processing Record 190 of Set 4 | lavrentiya
# Processing Record 191 of Set 4 | alampur
# Processing Record 192 of Set 4 | broken hill
# Processing Record 193 of Set 4 | havelock
# Processing Record 194 of Set 4 | kodiak
# Processing Record 195 of Set 4 | dzaoudzi
# Processing Record 196 of Set 4 | rawson
# Processing Record 197 of Set 4 | kirksville
# Processing Record 198 of Set 4 | kuminskiy
# Processing Record 199 of Set 4 | havoysund
# Processing Record 200 of Set 4 | kutum
# Processing Record 201 of Set 4 | upernavik
# Processing Record 202 of Set 4 | alta floresta
# Processing Record 203 of Set 4 | anadyr
# Processing Record 205 of Set 5 | hay river
# Processing Record 206 of Set 5 | muzhi
# Processing Record 207 of Set 5 | east london
# Processing Record 208 of Set 5 | dinard
# Processing Record 209 of Set 5 | ballina
# Processing Record 210 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 211 of Set 5 | praia
# Processing Record 212 of Set 5 | burns lake
# Processing Record 213 of Set 5 | pangnirtung
# Processing Record 214 of Set 5 | krasnoselkup
# Processing Record 215 of Set 5 | luwuk
# Processing Record 216 of Set 5 | stroby egede
# Processing Record 217 of Set 5 | cabo san lucas
# Processing Record 218 of Set 5 | gorin
# Processing Record 219 of Set 5 | kaitangata
# Processing Record 220 of Set 5 | tuktoyaktuk
# Processing Record 221 of Set 5 | port moresby
# Processing Record 222 of Set 5 | maceio
# Processing Record 223 of Set 5 | alcantara
# Processing Record 224 of Set 5 | lasa
# Processing Record 225 of Set 5 | azul
# Processing Record 226 of Set 5 | kailua
# Processing Record 227 of Set 5 | owando
# Processing Record 228 of Set 5 | bar harbor
# Processing Record 229 of Set 5 | talnakh
# Processing Record 230 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 231 of Set 5 | grand-santi
# Processing Record 232 of Set 5 | vestmannaeyjar
# Processing Record 233 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 234 of Set 5 | kanigoro
# Processing Record 235 of Set 5 | kahului
# Processing Record 236 of Set 5 | mwene-ditu
# Processing Record 237 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 238 of Set 5 | baijiantan
# Processing Record 239 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 240 of Set 5 | mozarlandia
# Processing Record 241 of Set 5 | naze
# Processing Record 242 of Set 5 | abu kamal
# Processing Record 243 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 244 of Set 5 | deputatskiy
# Processing Record 245 of Set 5 | leningradskiy
# Processing Record 246 of Set 5 | belyy yar
# Processing Record 247 of Set 5 | oussouye
# Processing Record 248 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 249 of Set 5 | butaritari
# Processing Record 250 of Set 5 | vao
# Processing Record 251 of Set 5 | margate
# Processing Record 252 of Set 5 | ola
# Processing Record 253 of Set 5 | mehamn
# Processing Record 254 of Set 5 | boa vista
# Processing Record 256 of Set 6 | rock sound
# Processing Record 257 of Set 6 | birao
# Processing Record 258 of Set 6 | chiredzi
# Processing Record 259 of Set 6 | verkhniy landekh
# Processing Record 260 of Set 6 | tulun
# Processing Record 261 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 262 of Set 6 | lomovka
# Processing Record 263 of Set 6 | puerto maldonado
# Processing Record 264 of Set 6 | kariba
# Processing Record 265 of Set 6 | caldas novas
# Processing Record 266 of Set 6 | ilhabela
# Processing Record 267 of Set 6 | norman wells
# Processing Record 268 of Set 6 | yulara
# Processing Record 269 of Set 6 | lusambo
# Processing Record 270 of Set 6 | tomatlan
# Processing Record 271 of Set 6 | komsomolskiy
# Processing Record 272 of Set 6 | provideniya
# Processing Record 273 of Set 6 | pionerskiy
# Processing Record 274 of Set 6 | sao felix do xingu
# Processing Record 275 of Set 6 | sakakah
# Processing Record 276 of Set 6 | carnarvon
# Processing Record 277 of Set 6 | ahipara
# Processing Record 278 of Set 6 | uige
# Processing Record 279 of Set 6 | kasulu
# Processing Record 280 of Set 6 | nuuk
# Processing Record 281 of Set 6 | khromtau
# Processing Record 282 of Set 6 | jizan
# Processing Record 283 of Set 6 | henties bay
# Processing Record 284 of Set 6 | port elizabeth
# Processing Record 285 of Set 6 | izumo
# Processing Record 286 of Set 6 | fort nelson
# Processing Record 287 of Set 6 | cayenne
# Processing Record 288 of Set 6 | vila
# Processing Record 289 of Set 6 | santa isabel
# Processing Record 290 of Set 6 | samana
# Processing Record 291 of Set 6 | shenjiamen
# Processing Record 292 of Set 6 | staraya toropa
# Processing Record 293 of Set 6 | dong hoi
# Processing Record 294 of Set 6 | avigliana
# Processing Record 295 of Set 6 | hualmay
# Processing Record 296 of Set 6 | benguela
# Processing Record 297 of Set 6 | maldonado
# Processing Record 298 of Set 6 | agoo
# Processing Record 299 of Set 6 | asau
# Processing Record 300 of Set 6 | tazmalt
# Processing Record 301 of Set 6 | bull savanna
# Processing Record 302 of Set 6 | la ronge
# Processing Record 303 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 304 of Set 6 | lyuban
# Processing Record 305 of Set 6 | peniche
# Processing Record 307 of Set 7 | bumbuna
# Processing Record 308 of Set 7 | poplar bluff
# Processing Record 309 of Set 7 | saint george
# Processing Record 310 of Set 7 | kaputa
# Processing Record 311 of Set 7 | mao
# Processing Record 312 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 313 of Set 7 | surok
# Processing Record 314 of Set 7 | gonaives
# Processing Record 315 of Set 7 | laguna
# Processing Record 316 of Set 7 | kashi
# Processing Record 317 of Set 7 | pisco
# Processing Record 318 of Set 7 | muli
# Processing Record 319 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 320 of Set 7 | muyezerskiy
# Processing Record 321 of Set 7 | nemuro
# Processing Record 322 of Set 7 | hamirpur
# Processing Record 323 of Set 7 | desterro
# Processing Record 324 of Set 7 | port hedland
# Processing Record 325 of Set 7 | mana
# Processing Record 326 of Set 7 | adamas
# Processing Record 327 of Set 7 | maumere
# Processing Record 328 of Set 7 | bozhou
# Processing Record 329 of Set 7 | manzhouli
# Processing Record 330 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 331 of Set 7 | pontianak
# Processing Record 332 of Set 7 | galveston
# Processing Record 333 of Set 7 | narsaq
# Processing Record 334 of Set 7 | harper
# Processing Record 335 of Set 7 | airai
# Processing Record 336 of Set 7 | pembroke
# Processing Record 337 of Set 7 | coihaique
# Processing Record 338 of Set 7 | xining
# Processing Record 339 of Set 7 | berlevag
# Processing Record 340 of Set 7 | sangar
# Processing Record 341 of Set 7 | kosjeric
# Processing Record 342 of Set 7 | ogbomosho
# Processing Record 343 of Set 7 | kigorobya
# Processing Record 344 of Set 7 | rawah
# Processing Record 345 of Set 7 | bayir
# Processing Record 346 of Set 7 | akyab
# Processing Record 347 of Set 7 | mendi
# Processing Record 348 of Set 7 | katangli
# Processing Record 349 of Set 7 | sao filipe
# Processing Record 350 of Set 7 | constitucion
# Processing Record 351 of Set 7 | svetlogorsk
# Processing Record 352 of Set 7 | arkhipovka
# Processing Record 353 of Set 7 | qidong
# Processing Record 354 of Set 7 | banjar
# Processing Record 355 of Set 7 | murchison
# Processing Record 356 of Set 7 | lorengau
# Processing Record 358 of Set 8 | wagar
# Processing Record 359 of Set 8 | grasse
# Processing Record 360 of Set 8 | udachnyy
# Processing Record 361 of Set 8 | aklavik
# Processing Record 362 of Set 8 | soria
# Processing Record 363 of Set 8 | nanortalik
# Processing Record 364 of Set 8 | santa ines
# Processing Record 365 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 366 of Set 8 | xiaolingwei
# Processing Record 367 of Set 8 | san andres
# Processing Record 368 of Set 8 | bismarck
# Processing Record 369 of Set 8 | dori
# Processing Record 370 of Set 8 | pingdingshan
# Processing Record 371 of Set 8 | caconda
# Processing Record 372 of Set 8 | busayra
# Processing Record 373 of Set 8 | takoradi
# Processing Record 374 of Set 8 | koumac
# Processing Record 375 of Set 8 | roanoke rapids
# Processing Record 376 of Set 8 | dianopolis
# City not found. Skipping...
# Processing Record 377 of Set 8 | cherskiy
# Processing Record 378 of Set 8 | gopichettipalaiyam
# City not found. Skipping...
# Processing Record 379 of Set 8 | nhulunbuy
# Processing Record 380 of Set 8 | kulachi
# Processing Record 381 of Set 8 | buin
# Processing Record 382 of Set 8 | grindavik
# Processing Record 383 of Set 8 | ossora
# Processing Record 384 of Set 8 | tilichiki
# Processing Record 385 of Set 8 | veraval
# Processing Record 386 of Set 8 | odweyne
# Processing Record 387 of Set 8 | hasaki
# Processing Record 388 of Set 8 | camacha
# Processing Record 389 of Set 8 | beringovskiy
# Processing Record 390 of Set 8 | swan hill
# Processing Record 391 of Set 8 | sao joao da barra
# Processing Record 392 of Set 8 | tagusao
# Processing Record 393 of Set 8 | north bend
# Processing Record 394 of Set 8 | sokoni
# Processing Record 395 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 396 of Set 8 | qaqortoq
# Processing Record 397 of Set 8 | jumla
# Processing Record 398 of Set 8 | kainantu
# Processing Record 399 of Set 8 | baruun-urt
# Processing Record 400 of Set 8 | traralgon
# Processing Record 401 of Set 8 | kupang
# Processing Record 402 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 403 of Set 8 | fortuna
# Processing Record 404 of Set 8 | dunedin
# Processing Record 405 of Set 8 | bubaque
# Processing Record 406 of Set 8 | treinta y tres
# Processing Record 407 of Set 8 | kedrovyy
# Processing Record 409 of Set 9 | sola
# Processing Record 410 of Set 9 | emerald
# Processing Record 411 of Set 9 | togur
# Processing Record 412 of Set 9 | marmaron
# City not found. Skipping...
# Processing Record 413 of Set 9 | bossangoa
# Processing Record 414 of Set 9 | jieshi
# Processing Record 415 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 416 of Set 9 | bamberg
# Processing Record 417 of Set 9 | te anau
# Processing Record 418 of Set 9 | thenzawl
# Processing Record 419 of Set 9 | lompoc
# Processing Record 420 of Set 9 | busia
# Processing Record 421 of Set 9 | ancud
# Processing Record 422 of Set 9 | vanino
# Processing Record 423 of Set 9 | jalu
# Processing Record 424 of Set 9 | san jeronimo
# Processing Record 425 of Set 9 | comodoro rivadavia
# Processing Record 426 of Set 9 | ambilobe
# Processing Record 427 of Set 9 | netivot
# Processing Record 428 of Set 9 | peterhead
# Processing Record 429 of Set 9 | severo-kurilsk
# Processing Record 430 of Set 9 | moen
# Processing Record 431 of Set 9 | starkville
# Processing Record 432 of Set 9 | iracoubo
# Processing Record 433 of Set 9 | fare
# Processing Record 434 of Set 9 | bonthe
# Processing Record 435 of Set 9 | manggar
# Processing Record 436 of Set 9 | najran
# Processing Record 437 of Set 9 | las tablas
# Processing Record 438 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 439 of Set 9 | ongandjera
# Processing Record 440 of Set 9 | barranca
# Processing Record 441 of Set 9 | hailey
# Processing Record 442 of Set 9 | palaikastron
# Processing Record 443 of Set 9 | yeppoon
# Processing Record 444 of Set 9 | serebryansk
# Processing Record 445 of Set 9 | pastrana
# Processing Record 446 of Set 9 | salalah
# Processing Record 447 of Set 9 | howard springs
# Processing Record 448 of Set 9 | valleyview
# Processing Record 449 of Set 9 | asfi
# Processing Record 450 of Set 9 | portland
# Processing Record 451 of Set 9 | gimli
# Processing Record 452 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 453 of Set 9 | mazamari
# Processing Record 454 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 455 of Set 9 | hambantota
# Processing Record 456 of Set 9 | ulyanovo
# City not found. Skipping...
# Processing Record 457 of Set 9 | kifri
# Processing Record 458 of Set 9 | rocha
# Processing Record 460 of Set 10 | calabozo
# Processing Record 461 of Set 10 | alcaniz
# Processing Record 462 of Set 10 | olafsvik
# Processing Record 463 of Set 10 | vostok
# Processing Record 464 of Set 10 | port shepstone
# Processing Record 465 of Set 10 | san javier
# Processing Record 466 of Set 10 | japura
# Processing Record 467 of Set 10 | kruisfontein
# Processing Record 468 of Set 10 | le port
# Processing Record 469 of Set 10 | kawalu
# Processing Record 470 of Set 10 | manavalakurichi
# Processing Record 471 of Set 10 | mitu
# Processing Record 472 of Set 10 | bridlington
# Processing Record 473 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 474 of Set 10 | lachi
# Processing Record 475 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 476 of Set 10 | meadow lake
# Processing Record 477 of Set 10 | gisborne
# Processing Record 478 of Set 10 | yaan
# Processing Record 479 of Set 10 | kargil
# Processing Record 480 of Set 10 | hervey bay
# Processing Record 481 of Set 10 | baykit
# Processing Record 482 of Set 10 | urucara
# Processing Record 483 of Set 10 | brunswick
# Processing Record 484 of Set 10 | port lavaca
# Processing Record 485 of Set 10 | arlit
# Processing Record 486 of Set 10 | chapais
# Processing Record 487 of Set 10 | mabaruma
# Processing Record 488 of Set 10 | thunder bay
# Processing Record 489 of Set 10 | temple
# Processing Record 490 of Set 10 | neuquen
# Processing Record 491 of Set 10 | bathsheba
# Processing Record 492 of Set 10 | chala
# Processing Record 493 of Set 10 | kanye
# Processing Record 494 of Set 10 | buraydah
# Processing Record 495 of Set 10 | vangaindrano
# Processing Record 496 of Set 10 | codrington
# Processing Record 497 of Set 10 | kikwit
# Processing Record 498 of Set 10 | la grande
# Processing Record 499 of Set 10 | santa rosa
# Processing Record 500 of Set 10 | zarand
# Processing Record 501 of Set 10 | bauchi
# Processing Record 502 of Set 10 | biltine
# Processing Record 503 of Set 10 | kysyl-syr
# Processing Record 504 of Set 10 | obidos
# Processing Record 505 of Set 10 | katherine
# Processing Record 506 of Set 10 | klaksvik
# Processing Record 507 of Set 10 | tucumcari
# Processing Record 508 of Set 10 | awbari
# Processing Record 509 of Set 10 | yerbogachen
# Processing Record 511 of Set 11 | takanabe
# Processing Record 512 of Set 11 | freeport
# Processing Record 513 of Set 11 | mitsamiouli
# Processing Record 514 of Set 11 | nan
# Processing Record 515 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 516 of Set 11 | lewiston
# Processing Record 517 of Set 11 | qingdao
# Processing Record 518 of Set 11 | olga
# Processing Record 519 of Set 11 | jaumave
# Processing Record 520 of Set 11 | oliver
# Processing Record 521 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 522 of Set 11 | sibu
# Processing Record 523 of Set 11 | riyadh
# Processing Record 524 of Set 11 | lingyuan
# Processing Record 525 of Set 11 | hastings
# Processing Record 526 of Set 11 | betanzos
# Processing Record 527 of Set 11 | van buren
# Processing Record 528 of Set 11 | gravdal
# Processing Record 529 of Set 11 | jati
# Processing Record 530 of Set 11 | sabang
# Processing Record 531 of Set 11 | severodvinsk
# Processing Record 532 of Set 11 | port-gentil
# Processing Record 533 of Set 11 | ramanuj ganj
# Processing Record 534 of Set 11 | praya
# Processing Record 535 of Set 11 | moerai
# Processing Record 536 of Set 11 | bilma
# Processing Record 537 of Set 11 | stromness
# Processing Record 538 of Set 11 | campo maior
# Processing Record 539 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 540 of Set 11 | villa union
# Processing Record 541 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 542 of Set 11 | brainerd
# Processing Record 543 of Set 11 | ingham
# Processing Record 544 of Set 11 | ouesso
# Processing Record 545 of Set 11 | atherton
# Processing Record 546 of Set 11 | vila do maio
# Processing Record 547 of Set 11 | asbestovskiy
# Processing Record 548 of Set 11 | capinota
# Processing Record 549 of Set 11 | makaha
# Processing Record 550 of Set 11 | waddan
# Processing Record 551 of Set 11 | porto seguro
# Processing Record 552 of Set 11 | coos bay
# Processing Record 553 of Set 11 | baturaja
# Processing Record 554 of Set 11 | sinnamary
# Processing Record 555 of Set 11 | tucupita
# Processing Record 556 of Set 11 | payakumbuh
# Processing Record 557 of Set 11 | evensk
# Processing Record 558 of Set 11 | nikki
# Processing Record 559 of Set 11 | asyut
# Processing Record 560 of Set 11 | matagami
# Processing Record 562 of Set 12 | weiser
# Processing Record 563 of Set 12 | kolosovka
# Processing Record 564 of Set 12 | machiques
# Processing Record 565 of Set 12 | rio gallegos
# Processing Record 566 of Set 12 | karabulak
# Processing Record 567 of Set 12 | nishihara
# Processing Record 568 of Set 12 | vagay
# Processing Record 569 of Set 12 | axim
# Processing Record 570 of Set 12 | mchinji
# Processing Record 571 of Set 12 | port lincoln
# Processing Record 572 of Set 12 | malaya vishera
# Processing Record 573 of Set 12 | nara
# Processing Record 574 of Set 12 | morant bay
# Processing Record 575 of Set 12 | taga
# Processing Record 576 of Set 12 | vardo
# Processing Record 577 of Set 12 | bonavista
# Processing Record 578 of Set 12 | makungu
# Processing Record 579 of Set 12 | xifeng
# Processing Record 580 of Set 12 | ojinaga
# Processing Record 581 of Set 12 | rumoi
# Processing Record 582 of Set 12 | mantua
# Processing Record 583 of Set 12 | puerto baquerizo moreno
# Processing Record 584 of Set 12 | batagay
# Processing Record 585 of Set 12 | torremolinos
# Processing Record 586 of Set 12 | sechura
# Processing Record 587 of Set 12 | westport
# Processing Record 588 of Set 12 | awjilah
# Processing Record 589 of Set 12 | barra patuca
# Processing Record 590 of Set 12 | dhidhdhoo
# Processing Record 591 of Set 12 | noumea
# Processing Record 592 of Set 12 | ust-nera
# Processing Record 593 of Set 12 | sumenep
# Processing Record 594 of Set 12 | boffa
# Processing Record 595 of Set 12 | guanica
# Processing Record 596 of Set 12 | youghal
# Processing Record 597 of Set 12 | joshimath
# Processing Record 598 of Set 12 | umm lajj
# Processing Record 599 of Set 12 | zhanakorgan
# Processing Record 600 of Set 12 | gizo
# Processing Record 601 of Set 12 | duncan
# Processing Record 602 of Set 12 | northam
# Processing Record 603 of Set 12 | lagunas
# Processing Record 604 of Set 12 | torbat-e jam
# Processing Record 605 of Set 12 | scarborough
# Processing Record 606 of Set 12 | balkanabat
# Processing Record 607 of Set 12 | saint-joseph
# Processing Record 608 of Set 12 | bilibino
# Processing Record 609 of Set 12 | saint-pierre
# Processing Record 610 of Set 12 | grand gaube
# Processing Record 611 of Set 12 | yuanping
# Processing Record 613 of Set 13 | mayo
# Processing Record 614 of Set 13 | salinas
# Processing Record 615 of Set 13 | killarney
# Processing Record 616 of Set 13 | port-cartier
# Processing Record 617 of Set 13 | dawei
# Processing Record 618 of Set 13 | havre-saint-pierre
# Processing Record 619 of Set 13 | umm kaddadah
# Processing Record 620 of Set 13 | chivay
# Processing Record 621 of Set 13 | thiruvananthapuram
# Processing Record 622 of Set 13 | kharan
# Processing Record 623 of Set 13 | quatre cocos
# Processing Record 624 of Set 13 | vancouver
# Processing Record 625 of Set 13 | san quintin
# Processing Record 626 of Set 13 | wonthaggi
# Processing Record 627 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 628 of Set 13 | sturgis
# Processing Record 629 of Set 13 | ishigaki
# Processing Record 630 of Set 13 | yenagoa
# Processing Record 631 of Set 13 | esso
# Processing Record 632 of Set 13 | gorom-gorom
# Processing Record 633 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 634 of Set 13 | chernyshevsk
# Processing Record 635 of Set 13 | mafeteng
# Processing Record 636 of Set 13 | samarai
# Processing Record 637 of Set 13 | bambanglipuro
# Processing Record 638 of Set 13 | juba
# Processing Record 639 of Set 13 | hailar
# Processing Record 640 of Set 13 | dibulla
# Processing Record 641 of Set 13 | richards bay
# Processing Record 642 of Set 13 | zalantun
# Processing Record 643 of Set 13 | mersin
# Processing Record 644 of Set 13 | sulangan
# Processing Record 645 of Set 13 | abha
# Processing Record 646 of Set 13 | prince george
# Processing Record 647 of Set 13 | sovetskiy
# Processing Record 648 of Set 13 | nyurba
# Processing Record 649 of Set 13 | rantauprapat
# Processing Record 650 of Set 13 | asosa
# Processing Record 651 of Set 13 | sterling
# Processing Record 652 of Set 13 | omsukchan
# Processing Record 653 of Set 13 | itatskiy
# Processing Record 654 of Set 13 | manbij
# Processing Record 655 of Set 13 | candelaria
# Processing Record 656 of Set 13 | kerrville
# Processing Record 657 of Set 13 | hovd
# Processing Record 658 of Set 13 | beaverlodge
# Processing Record 659 of Set 13 | mykhaylivka
# Processing Record 660 of Set 13 | tigil
# Processing Record 661 of Set 13 | vila velha
# Processing Record 662 of Set 13 | nosy varika
# Processing Record 664 of Set 14 | chemodanovka
# Processing Record 665 of Set 14 | flin flon
# Processing Record 666 of Set 14 | marienburg
# Processing Record 667 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 668 of Set 14 | shahreza
# Processing Record 669 of Set 14 | pell city
# Processing Record 670 of Set 14 | trofors
# Processing Record 671 of Set 14 | kazanskaya
# Processing Record 672 of Set 14 | itaituba
# Processing Record 673 of Set 14 | wanning
# Processing Record 674 of Set 14 | okhotsk
# Processing Record 675 of Set 14 | avera
# Processing Record 676 of Set 14 | kapchorwa
# Processing Record 677 of Set 14 | warrington
# Processing Record 678 of Set 14 | divnomorskoye
# Processing Record 679 of Set 14 | yangambi
# Processing Record 680 of Set 14 | gambela
# Processing Record 681 of Set 14 | aksu
# Processing Record 682 of Set 14 | sibolga
# Processing Record 683 of Set 14 | la sarre
# Processing Record 684 of Set 14 | neryungri
# Processing Record 685 of Set 14 | sandviken
# Processing Record 686 of Set 14 | pundaguitan
# Processing Record 687 of Set 14 | san cristobal
# Processing Record 688 of Set 14 | bad freienwalde
# Processing Record 689 of Set 14 | cumaribo
# City not found. Skipping...
# Processing Record 690 of Set 14 | vaike-maarja
# Processing Record 691 of Set 14 | adolfo lopez mateos
# Processing Record 692 of Set 14 | ambon
# Processing Record 693 of Set 14 | bairiki
# Processing Record 694 of Set 14 | port blair
# Processing Record 695 of Set 14 | lae
# Processing Record 696 of Set 14 | mago
# Processing Record 697 of Set 14 | yumen
# Processing Record 698 of Set 14 | sohag
# Processing Record 699 of Set 14 | ocampo
# Processing Record 700 of Set 14 | qasigiannguit
# Processing Record 701 of Set 14 | necochea
# Processing Record 702 of Set 14 | teluk nibung
# Processing Record 703 of Set 14 | puerto vallarta
# Processing Record 704 of Set 14 | middle island
# Processing Record 705 of Set 14 | jinchang
# Processing Record 706 of Set 14 | pangai
# Processing Record 707 of Set 14 | tokoroa
# Processing Record 708 of Set 14 | seoul
# Processing Record 709 of Set 14 | cozumel
# Processing Record 710 of Set 14 | nipawin
# Processing Record 711 of Set 14 | millinocket
# Processing Record 712 of Set 14 | semey
# Processing Record 713 of Set 14 | acobamba
# Processing Record 715 of Set 15 | luba
# Processing Record 716 of Set 15 | hobyo
# Processing Record 717 of Set 15 | porto nacional
# Processing Record 718 of Set 15 | kokologo
# Processing Record 719 of Set 15 | halifax
# Processing Record 720 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 721 of Set 15 | nyuksenitsa
# Processing Record 722 of Set 15 | mikhaylovka
# Processing Record 723 of Set 15 | beloha
# Processing Record 724 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 725 of Set 15 | intipuca
# Processing Record 726 of Set 15 | morehead
# Processing Record 727 of Set 15 | monrovia
# Processing Record 728 of Set 15 | derbent
# Processing Record 729 of Set 15 | the valley
# Processing Record 730 of Set 15 | jonesboro
# Processing Record 731 of Set 15 | jiuquan
# Processing Record 732 of Set 15 | curvelo
# Processing Record 733 of Set 15 | lilienthal
# Processing Record 734 of Set 15 | beachwood
# Processing Record 735 of Set 15 | ashdod
# Processing Record 736 of Set 15 | zelenoborsk
# Processing Record 737 of Set 15 | karratha
# Processing Record 738 of Set 15 | palmer
# Processing Record 739 of Set 15 | vallenar
# Processing Record 740 of Set 15 | houma
# Processing Record 741 of Set 15 | dalvik
# Processing Record 742 of Set 15 | nago
# Processing Record 743 of Set 15 | lingao
# Processing Record 744 of Set 15 | los llanos de aridane
# Processing Record 745 of Set 15 | mocuba
# Processing Record 746 of Set 15 | lienz
# Processing Record 747 of Set 15 | ourem
# Processing Record 748 of Set 15 | coquimbo
# Processing Record 749 of Set 15 | honiara
# Processing Record 750 of Set 15 | cabedelo
# Processing Record 751 of Set 15 | kirakira
# Processing Record 752 of Set 15 | santa marta
# Processing Record 753 of Set 15 | san jose
# Processing Record 754 of Set 15 | logresti
# Processing Record 755 of Set 15 | ixtapa
# Processing Record 756 of Set 15 | chapleau
# Processing Record 757 of Set 15 | moravsky beroun
# Processing Record 758 of Set 15 | stornoway
# Processing Record 759 of Set 15 | corinto
# Processing Record 760 of Set 15 | mogadishu
# Processing Record 761 of Set 15 | tarnalelesz
# Processing Record 762 of Set 15 | galesong
# Processing Record 763 of Set 15 | the pas
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hamilton      US  39.1834  -84.5333     55.40        91          90
# 1           Broome      US  42.2506  -75.8330     43.20        87          90
# 2          Ushuaia      AR -54.8000  -68.3000     33.46        80          75
# 3          Husavik      IS  66.0449  -17.3389     28.31        96         100
# 4           Fallon      US  39.4735 -118.7774     52.29        75          90
# 5          Sambava      MG -14.2667   50.1667     77.02        87          86
# 6         Hokitika      NZ -42.7167  170.9667     56.25        87         100
# 7        Jamestown      US  42.0970  -79.2353     44.29        96          75
# 8             Nome      US  64.5011 -165.4064     32.07        75           1
# 9  Santiago De Cao      PE  -7.9589  -79.2392     62.33        88          45
#
#    Wind Speed Current Description
# 0        1.01     overcast clouds
# 1        1.01     overcast clouds
# 2       11.50          light snow
# 3        2.95     overcast clouds
# 4        0.00     overcast clouds
# 5        4.52     overcast clouds
# 6        4.43     overcast clouds
# 7        1.99       broken clouds
# 8        3.44           clear sky
# 9       12.46    scattered clouds

# %%
#Create the output file (CSV)
output_data_file = "WeatherPy_Database.csv"

#Export the output file
city_data_df.to_csv(output_data_file,index_label="City_ID")
